# %% [markdown]
# #CANCER SCC

# %%
import seaborn as sns
import matplotlib.pylab as plt
import numpy as np

import os
bins = np.linspace(0, 1, 100)
from matplotlib import pyplot
path = '/home/wsai/GradCAM1/ExampleGBV6/SCC/'
list_md = os.listdir(path)
print(len(list_md))
##while phase 4 usr orginal data
for i in list_md:
    plt.clf()
#     try:
    heat = np.load(path + i)
#         plt.subplots(1, 2, sharey=True, tight_layout=True)
    plt.title('Heatmap for' + i[0:7], fontsize=20)
    plt.xlabel("pixel of activation map \(8x8\)", fontsize=5)
    plt.ylabel("patchs", fontsize=5)
    ax = sns.heatmap(heat[:50], vmax=1000)
    plt.show()
    plt.ylim(0, 5)
    plt.xlim(0,200000)
    plt.hist(heat[:50],bins=100)

#     sns.distplot(heat[:50].flatten(),bins)
#     plt.hist(heat[:50],bins=100)

    plt.show()
#         plt.savefig(path + i[0:7] + '.png')
    print("print max value %s"%heat[:50].max())
#     except:
#         None
#         print(i[0:7])
        
    plt.pause(0.1)
# Out:
# 19
# print max value 145696.90480820974
# print max value 132323.73957495994
# print max value 196765.2967494172
# print max value 139462.08188229724
# print max value 80240.07825438063
# print max value 157151.35916397022
# print max value 150315.67872574323
# print max value 94388.68058754766
# print max value 68596.46425798238
# print max value 114849.90082051326
# print max value 151563.86872325186
# print max value 169389.566684835
# print max value 92706.58237654064
# print max value 140999.4168284398
# print max value 64340.62858801811
# print max value 202897.50236760871
# print max value 78903.82350744407
# print max value 176906.97396113075
# print max value 136521.67590836203

# %% [markdown]
# #CANCER ADC

# %%
import seaborn as sns
import matplotlib.pylab as plt
import numpy as np
import os
path = '/home/wsai/GradCAM1/ExampleGBV6/ADC/'
list_md = os.listdir(path)
print(len(list_md))
##while phase 4 usr orginal data
for i in list_md:
    plt.clf()
    try:
        heat = np.load(path + i)
        print("print max value %s"%heat[:50].max())
#         plt.subplots(1, 2, sharey=True, tight_layout=True)
        plt.title('Heatmap for' + i[0:7], fontsize=20)
        plt.xlabel("pixel of activation map \(8x8\)", fontsize=5)
        plt.ylabel("patchs", fontsize=5)

        ax = sns.heatmap(heat[:50], vmax=1000)

        plt.show()
        plt.ylim(0, 5)
        plt.xlim(0,200000)
        plt.hist(heat[:50],n_bins=1000)
        plt.show()
#         plt.savefig(path + i[0:7] + '.png')
        
    except:
        None
#         print(i[0:7])
        
    plt.pause(0.1)
# Out:
# 18
# print max value 128408.8846871187
# print max value 81362.04902382498
# print max value 94942.47381252144
# print max value 109619.60476225559
# print max value 114711.6991043195
# print max value 115735.52987204283
# print max value 161668.27639522028
# print max value 132502.70263812016
# print max value 101247.03263221425
# print max value 146527.31394455582
# print max value 122353.48955596983
# print max value 117650.96484455706
# print max value 190582.1510895169
# print max value 144743.34355295263
# print max value 28640.054872884182
# print max value 70152.05850143766
# print max value 179587.52822550386
# print max value 130876.87933066602

# %% [markdown]
# #Cancer Small cell

# %%
import seaborn as sns
import matplotlib.pylab as plt
import numpy as np
import os
path = '/home/wsai/GradCAM1/ExampleGBV6/SmallCell/'
list_md = os.listdir(path)
print(len(list_md))
##while phase 4 usr orginal data
for i in list_md:
    plt.clf()
    try:
        heat = np.load(path + i)
        print("print max value %s"%heat[:50].max())
#         plt.subplots(1, 2, sharey=True, tight_layout=True)
        plt.title('Heatmap for' + i[0:7], fontsize=20)
        plt.xlabel("pixel of activation map \(8x8\)", fontsize=5)
        plt.ylabel("patchs", fontsize=5)
        ax = sns.heatmap(heat[:50], vmax=10000)
        plt.show()
        plt.ylim(0, 5)
        plt.xlim(0,200000)
        plt.hist(heat[:50],n_bins=1000)
        plt.show()
#         plt.savefig(path + i[0:7] + '.png')
        print("print max value %s"%heat[:50].max())
    except:
        None
#         print(i[0:7])
        
    plt.pause(0.1)
# Out:
# 18
# print max value 105699.1516180405
# print max value 60576.53375272505
# print max value 190918.9899468539
# print max value 107745.104636251
# print max value 209854.33245412773
# print max value 185170.28443994466
# print max value 71304.76696257587
# print max value 218490.11638992664
# print max value 80363.48309694945
# print max value 183287.53137987116
# print max value 159981.48143665912
# print max value 110795.53766945685
# print max value 135041.24283908773
# print max value 171737.6924126963
# print max value 72652.63155291788
# print max value 145155.34688230534
# print max value 240472.44931148458
# print max value 105815.78825015575

# %% [markdown]
# #lCNEC

# %%
import seaborn as sns
import matplotlib.pylab as plt
import numpy as np
import os
path = '/home/wsai/GradCAM1/ExampleGBV6/LCNEC/'
list_md = os.listdir(path)
print(len(list_md))
##while phase 4 usr orginal data
for i in list_md:
    plt.clf()
    try:
        heat = np.load(path + i)
        print("print max value %s"%heat[:50].max())
#         plt.subplots(1, 2, sharey=True, tight_layout=True)
        plt.title('Heatmap for' + i[0:7], fontsize=20)
        plt.xlabel("pixel of activation map \(8x8\)", fontsize=5)
        plt.ylabel("patchs", fontsize=5)
        ax = sns.heatmap(heat[:50], vmax=10000)
        plt.show()
#         plt.ylim(0, 5)
        plt.xlim(0,200000)
        plt.hist(heat[:50],n_bins=1000)
        plt.show()
#         plt.savefig(path + i[0:7] + '.png')
        print("print max value %s"%heat[:50].max())
    except:
        None
#         print(i[0:7])
        
    plt.pause(0.1)
# Out:
# 11
# print max value 183409.05517063715
# print max value 38591.21343220578
# print max value 195934.28589314423
# print max value 250998.0892767813
# print max value 95154.67511335434
# print max value 205648.4943077154
# print max value 114662.22892640517
# print max value 191550.05707840435
# print max value 157860.66358441318
# print max value 208520.9816241758
# print max value 117104.03559874414

# %% [markdown]
# #Normal

# %%
import seaborn as sns
import matplotlib.pylab as plt
import numpy as np
import os
path = '/home/wsai/GradCAM1/ExampleGBV6/Normal/'
list_md = os.listdir(path)
print(len(list_md))
##while phase 4 usr orginal data
for i in list_md:
    plt.clf()
    try:
        heat = np.load(path + i)
        print("print max value %s"%heat[:50].max())
#         plt.subplots(1, 2, sharey=True, tight_layout=True)
        plt.title('Heatmap for' + i[0:7], fontsize=20)
        plt.xlabel("pixel of activation map \(8x8\)", fontsize=5)
        plt.ylabel("patchs", fontsize=5)
        ax = sns.heatmap(heat[:50], vmax=1000)
        plt.show()
        plt.ylim(0, 5)
        plt.xlim(0,200000)
        plt.hist(heat[:50],n_bins=1000)
        plt.show()
#         plt.savefig(path + i[0:7] + '.png')
        print("print max value %s"%heat[:50].max())
    except:
        None
#         print(i[0:7])
        
    plt.pause(0.1)
# Out:
# 47
# print max value 8988.416401519207
# print max value 18319.314511668563
# print max value 18383.37022528157
# print max value 7924.006765083825
# print max value 2804.009818780476
# print max value 12818.319712177763
# print max value 6033.171381275973
# print max value 10380.45614070815
# print max value 15918.85476554881
# print max value 27839.618839161238
# print max value 166.0993280538205
# print max value 25109.02893967554
# print max value 9147.543156057947
# print max value 606.0981193617497
# print max value 6529.050820118705
# print max value 24174.80013946451
# print max value 7634.6201624884825
# print max value 21681.821119737928
# print max value 12489.287572831216
# print max value 6033.377459774336
# print max value 23019.428264207225
# print max value 16.780608337457075
# print max value 28969.900238019763
# print max value 7503.429944873447
# print max value 6648.9713905786775
# print max value 10035.048732513009
# print max value 42.108042511053696
# ...
